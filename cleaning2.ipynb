# %%
import pandas as pd


df3 = pd.read_csv('CLEANEDForder_segmentation_0.0.csv')

# %%
df3
# Out:
#        Unnamed: 0  customer  order  total_items  discount%  weekday  hour  \
# 0               0         0      0     0.291045      23.03        4    13
# 1               1         0      1     0.238806       1.22        5    13
# 2               2         0      2     0.335821      18.08        4    13
# 3               3         1      3     0.380597      16.51        1    12
# 4               4         1      4     0.350746      18.31        2    11
# ...           ...       ...    ...          ...        ...      ...   ...
# 28096       29989     10231  29989     0.067164       7.70        1     0
# 28097       29990     10231  29990     0.119403       8.97        7    12
# 28098       29991     10231  29991     0.067164       3.92        5    11
# 28099       29997     10237  29997     0.358209       0.00        4    17
# 28100       29998     10237  29998     0.029851       0.00        5    10
#
#        Food%  Fresh%  Drinks%  Home%  Beauty%  Health%  Baby%  Pets%  labels  \
# ...

# %%
df3['input_text'] = (
    "customer: " + df3['customer'].astype(str) +
    "; order: " + df3['order'].astype(str) +
    "; total_items: " + df3['total_items'].astype(str) +
    "; discount%: " + df3['discount%'].astype(str) +
    "; weekday: " + df3['weekday'].astype(str) +
    "; hour: " + df3['hour'].astype(str) +
    "; Food%: " + df3['Food%'].astype(str) +
    "; Fresh%: " + df3['Fresh%'].astype(str) +
    "; Drinks%: " + df3['Drinks%'].astype(str) +
    "; Home%: " + df3['Home%'].astype(str) +
    "; Beauty%: " + df3['Beauty%'].astype(str) +
    "; Health%: " + df3['Health%'].astype(str) +
    "; Baby%: " + df3['Baby%'].astype(str) +
    "; Pets%: " + df3['Pets%'].astype(str) + "; labels: " + df3['labels'].astype(str))

df3['target_text'] = df3['class'].astype(str)

# %%
df3
# Out:
#        Unnamed: 0  customer  order  total_items  discount%  weekday  hour  \
# 0               0         0      0     0.291045      23.03        4    13
# 1               1         0      1     0.238806       1.22        5    13
# 2               2         0      2     0.335821      18.08        4    13
# 3               3         1      3     0.380597      16.51        1    12
# 4               4         1      4     0.350746      18.31        2    11
# ...           ...       ...    ...          ...        ...      ...   ...
# 28096       29989     10231  29989     0.067164       7.70        1     0
# 28097       29990     10231  29990     0.119403       8.97        7    12
# 28098       29991     10231  29991     0.067164       3.92        5    11
# 28099       29997     10237  29997     0.358209       0.00        4    17
# 28100       29998     10237  29998     0.029851       0.00        5    10
#
#        Food%  Fresh%  Drinks%  Home%  Beauty%  Health%  Baby%  Pets%  labels  \
# ...

# %%
df3.to_csv('cleaned_Forder_segmentation_0.0.csv', index=False)

# %%
df4 = pd.read_csv('CLEANEDamazon_sales_dataset.csv')
df4
# Out:
#                        Date  Store  Dept  Unnamed: 3  Weekly_Sales  Type  \
# 0       2019-02-05 00:00:00      1     1  05/02/2019      0.342576     0
# 1       2019-02-05 00:00:00      9    97  05/02/2019      0.009188     1
# 2       2019-02-05 00:00:00      9    85  05/02/2019      0.009537     1
# 3       2019-02-05 00:00:00      8    80  05/02/2019      0.118953     0
# 4       2019-02-05 00:00:00      9    55  05/02/2019      0.152888     1
# ...                     ...    ...   ...         ...           ...   ...
# 365959  2021-10-26 00:00:00      2    26  26/10/2021      0.127259     0
# 365960  2021-10-26 00:00:00     38    23  26/10/2021      0.000730     2
# 365961  2021-10-26 00:00:00     27     6  26/10/2021      0.073391     0
# 365962  2021-10-26 00:00:00     36    40  26/10/2021      0.140418     0
# 365963  2021-10-26 00:00:00     45    98  26/10/2021      0.014800     1
#
#           Size  Temperature  Fuel_Price       CPI  ...  IsHoliday  Year  \
# ...

# %%
df4['input_text'] = (
    "Date: " + df4['Date'].astype(str) + "; " +
    "Store: " + df4['Store'].astype(str) + "; " +
    "Dept: " + df4['Dept'].astype(str) + "; " +
    "Unnamed: 3: " + df4['Unnamed: 3'].astype(str) + "; " +
    "Type: " + df4['Type'].astype(str) + "; " +
    "Size: " + df4['Size'].astype(str) + "; " +
    "Temperature: " + df4['Temperature'].astype(str) + "; " +
    "Fuel_Price: " + df4['Fuel_Price'].astype(str) + "; " +
    "CPI: " + df4['CPI'].astype(str) + "; " +
    "Unemployment: " + df4['Unemployment'].astype(str) + "; " +
    "IsHoliday: " + df4['IsHoliday'].astype(str) + "; " +
    "Year: " + df4['Year'].astype(str) + "; " +
    "Month: " + df4['Month'].astype(str) + "; " +
    "Week: " + df4['Week'].astype(str) + "; " +
    "max: " + df4['max'].astype(str) + "; " +
    "min: " + df4['min'].astype(str) + "; " +
    "mean: " + df4['mean'].astype(str) + "; " +
    "median: " + df4['median'].astype(str) + "; " +
    "std: " + df4['std'].astype(str) + "; " +
    "Total_MarkDown: " + df4['Total_MarkDown'].astype(str)
)

df4['target_text'] = df4['Weekly_Sales'].astype(str)

# %%
df4
# Out:
#                        Date  Store  Dept  Unnamed: 3  Weekly_Sales  Type  \
# 0       2019-02-05 00:00:00      1     1  05/02/2019      0.342576     0
# 1       2019-02-05 00:00:00      9    97  05/02/2019      0.009188     1
# 2       2019-02-05 00:00:00      9    85  05/02/2019      0.009537     1
# 3       2019-02-05 00:00:00      8    80  05/02/2019      0.118953     0
# 4       2019-02-05 00:00:00      9    55  05/02/2019      0.152888     1
# ...                     ...    ...   ...         ...           ...   ...
# 365959  2021-10-26 00:00:00      2    26  26/10/2021      0.127259     0
# 365960  2021-10-26 00:00:00     38    23  26/10/2021      0.000730     2
# 365961  2021-10-26 00:00:00     27     6  26/10/2021      0.073391     0
# 365962  2021-10-26 00:00:00     36    40  26/10/2021      0.140418     0
# 365963  2021-10-26 00:00:00     45    98  26/10/2021      0.014800     1
#
#           Size  Temperature  Fuel_Price       CPI  ...  Month  Week       max  \
# ...

# %%
df4.to_csv('cleaned_amazon_sales_dataset.csv', index=False)
